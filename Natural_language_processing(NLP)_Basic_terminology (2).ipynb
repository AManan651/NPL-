# %% [markdown]
# TEXT PRE-PROCESSING
#
# 1.   Tokenizaion( sentences )
# 2.   Stemming
# 3.   Lemmatization
# 4.   Stopwords removal

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
corpus="""Hello Welcome, to Krish Naik's NLP Tutorial.
Please do watch the entire course! to become expert in NLP.
"""

# %%
corpus
# Out:
# "Hello Welcome, to Krish Naik's NLP Tutorial.\nPlease do watch the entire course! to become expert in NLP.\n"

# %%
#Tokanization technique 1
## Sentance -->> paragraphs
""" nltk.sent tokenize - search by it """
from nltk.tokenize import sent_tokenize
documents=sent_tokenize(corpus)
print(documents)
# Out:
# ["Hello Welcome, to Krish Naik's NLP Tutorial.", 'Please do watch the entire course!', 'to become expert in NLP.']

# %%
for i in documents:
  print(i)
# Out:
# Hello Welcome, to Krish Naik's NLP Tutorial.
# Please do watch the entire course!
# to become expert in NLP.

# %%
## documents-- >> words
from nltk.tokenize import word_tokenize
token=word_tokenize(corpus)
token
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorial',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %% [markdown]
#  Stemming

# %%
##Stemming {going, gone, goes ->> go }
##Porter Stemmer
from nltk.stem import PorterStemmer
stemming=PorterStemmer()
for i in token:
  print(stemming.stem(i))
# Out:
# hello
# welcom
# ,
# to
# krish
# naik
# 's
# nlp
# tutori
# .
# pleas
# do
# watch
# the
# entir
# cours
# !
# to
# becom
# expert
# in
# nlp
# .

# %% [markdown]
# Mejor disadvantage is some times word's meaning will chnage.

# %%
##Stemming {going, gone, goes ->> go }
##Regexp Stemmer
from nltk.stem import RegexpStemmer
stemming=RegexpStemmer('ing$|s$|ed$|able$', min=4)

# %% [markdown]
# Explanation of RegexpStemmer('ing$|s$|ed$|able$', min=4):
# 'ing$|s$|ed$|able$':
#
# This is a regular expression pattern that matches the suffixes ing, s, ed, and able at the end of a word.
# The | symbol acts as an OR operator, meaning the stemmer will look for any of these suffixes in the word.
# The $ symbol indicates the end of the word, so the suffixes must appear at the end to be considered a match.
# min=4:
#
# This parameter specifies that the stemmer should only consider words that are at least 4 characters long.
# If a word is shorter than this length, it won't be stemmed, even if it ends with one of the specified suffixes.

# %%
for i in token:
  print(stemming.stem(i))
# Out:
# Hello
# Welcome
# ,
# to
# Krish
# Naik
# 's
# NLP
# Tutorial
# .
# Please
# do
# watch
# the
# entire
# course
# !
# to
# become
# expert
# in
# NLP
# .

# %%
from nltk.stem import SnowballStemmer
Snowballstemmer = SnowballStemmer('english') # Define the stemmer object
for i in token:
  print(Snowballstemmer.stem(i)) # Use the correct variable name here
# Out:
# hello
# welcom
# ,
# to
# krish
# naik
# 's
# nlp
# tutori
# .
# pleas
# do
# watch
# the
# entir
# cours
# !
# to
# becom
# expert
# in
# nlp
# .

# %%
##kon kon word change hoise....
from nltk.stem.snowball import SnowballStemmer
Snowballstemmer = SnowballStemmer('english')
for i in token:
  print(i,"<<<<>>>>", Snowballstemmer.stem(i))
# Out:
# Hello <<<<>>>> hello
# Welcome <<<<>>>> welcom
# , <<<<>>>> ,
# to <<<<>>>> to
# Krish <<<<>>>> krish
# Naik <<<<>>>> naik
# 's <<<<>>>> 's
# NLP <<<<>>>> nlp
# Tutorial <<<<>>>> tutori
# . <<<<>>>> .
# Please <<<<>>>> pleas
# do <<<<>>>> do
# watch <<<<>>>> watch
# the <<<<>>>> the
# entire <<<<>>>> entir
# course <<<<>>>> cours
# ! <<<<>>>> !
# to <<<<>>>> to
# become <<<<>>>> becom
# expert <<<<>>>> expert
# in <<<<>>>> in
# NLP <<<<>>>> nlp
# . <<<<>>>> .

# %% [markdown]
# The SnowballStemmer is another stemming algorithm provided by the NLTK library. It is a more advanced and refined version of the Porter Stemmer, created by the same inventor, Martin Porter.
# Key Features of SnowballStemmer:
# Language Support: The Snowball Stemmer supports multiple languages, including English, French, German, Spanish, Dutch, Italian, Portuguese, Romanian, Russian, Swedish, and others.
# Improved Rules: It uses a more complex set of rules compared to the original Porter Stemmer, making it more suitable for a wider range of languages and more accurate in many cases.
# Customizable: You can choose the language you want the stemmer to operate on, which allows for language-specific stemming
#
# EXAMPLE:::
# from nltk.stem import SnowballStemmer
#
# # Create a SnowballStemmer for English
# stemmer = SnowballStemmer("english")
#
# # Examples
# words = ['running', 'dogs', 'cried', 'capable', 'happier', 'flying']
# stemmed_words = [stemmer.stem(word) for word in words]
#
# print(stemmed_words)

# %% [markdown]
# THOUGH stemming is the best way to solve but it is not 100% perfect. So the best solution is lemmatizing the words

# %%
import nltk
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
for i in token:
  print(lemmatizer.lemmatize(i))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Hello
# Welcome
# ,
# to
# Krish
# Naik
# 's
# NLP
# Tutorial
# .
# Please
# do
# watch
# the
# entire
# course
# !
# to
# become
# expert
# in
# NLP
# .

# %% [markdown]
# STOP WORDS REMOVAL

# %%
# !pip install nltk
import nltk # Import the nltk module
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
# ...

# %% [markdown]
# # **now we do entire process **

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
stopwords.words('english')



from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
paragraph = """Today, I am here to deliver a speech on Dr APJ Abdul Kalam. APJ Abdul Kalam was born to Jainulabdeen and Ashiamma on October 15, 1931. His father was a boat owner and his mother was a homemaker. His family's economic situation was not strong, so at an early age, he began helping his family financially.


He graduated in 1955 from the Madras Institute of Technology and graduated from St. Joseph's College, Tiruchirappalli, in Aerospace Engineering. He joined the Defense Research and Development Organization's (DRDO) Aeronautical Development Base as a Chief Scientist after his graduation. He won credit as Project Director-General for making India's first indigenous satellite (SLV III) rocket. It was his ultimate support that brought nuclear power to India. In July 1992, he was appointed Scientific Advisor to the Indian Ministry of Defence. As a national counsellor, he played a significant role in the world-famous nuclear tests at Pokhran II. In 1981, he was awarded the Padma Bhushan Award, in 1909 the Padma Vibhushan, and in 1997 the highest civilian award of India' Bharat Ratna 'for modernizing the defence technology of India and his outstanding contribution.


From July 25, 2002 - July 25, 2007, he served as President of India, becoming famous among Indians and receiving a lot of attention from Indian youth. He became popular as the People's President. Kalam worked as a professor, chancellor, and assistant at many institutions after leaving office. He experienced serious cardiac arrest on the evening of July 27, 2015, and fell unconscious and died 2 hours later.


In 1999, Kalam published his autobiography and a book called The Wings of Fire. He has written many other books that are useful to the people of every generation."""
sentences=nltk.sent_tokenize(paragraph)

sentences
# Out:
# ['Today, I am here to deliver a speech on Dr APJ Abdul Kalam.',
#  'APJ Abdul Kalam was born to Jainulabdeen and Ashiamma on October 15, 1931.',
#  'His father was a boat owner and his mother was a homemaker.',
#  "His family's economic situation was not strong, so at an early age, he began helping his family financially.",
#  "He graduated in 1955 from the Madras Institute of Technology and graduated from St. Joseph's College, Tiruchirappalli, in Aerospace Engineering.",
#  "He joined the Defense Research and Development Organization's (DRDO) Aeronautical Development Base as a Chief Scientist after his graduation.",
#  "He won credit as Project Director-General for making India's first indigenous satellite (SLV III) rocket.",
#  'It was his ultimate support that brought nuclear power to India.',
#  'In July 1992, he was appointed Scientific Advisor to the Indian Ministry of Defence.',
# ...

# %%
##apply stopword and filter it then apply stemming / lemmatizing
lemmatizer = WordNetLemmatizer() # Create an instance of WordNetLemmatizer
for i in range(len(sentences)):
  words=nltk.word_tokenize(sentences[i])
  words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in set(stopwords.words('english'))] # Now you can call lemmatize()
  sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['today , i deliver speech dr apj abdul kalam .',
#  'apj abdul kalam born jainulabdeen ashiamma october 15 , 1931 .',
#  'his father boat owner mother homemaker .',
#  "his family 's economic situation strong , early age , began helping family financially .",
#  "he graduated 1955 madras institute technology graduated st. joseph 's college , tiruchirappalli , aerospace engineering .",
#  "he joined defense research development organization 's ( drdo ) aeronautical development base chief scientist graduation .",
#  "he credit project director-general making india 's first indigenous satellite ( slv iii ) rocket .",
#  'it ultimate support brought nuclear power india .',
#  'in july 1992 , appointed scientific advisor indian ministry defence .',
#  'a national counsellor , played significant role world-famous nuclear test pokhran ii .',
# ...

# %% [markdown]
# Parts of speech

# %%
text="""Machine Learning: This is a field of AI that focuses on developing algorithms that allow computers to learn from and make decisions based on data. Machine learning encompasses a wide range of techniques, including supervised learning, unsupervised learning, and reinforcement learning. Common algorithms include decision trees, support vector machines (SVMs), k-nearest neighbors (k-NN), and linear regression, among others"""

# %%
text
# Out:
# 'Machine Learning: This is a field of AI that focuses on developing algorithms that allow computers to learn from and make decisions based on data. Machine learning encompasses a wide range of techniques, including supervised learning, unsupervised learning, and reinforcement learning. Common algorithms include decision trees, support vector machines (SVMs), k-nearest neighbors (k-NN), and linear regression, among others'

# %%
sent=nltk.sent_tokenize(text)
sent
# Out:
# ...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ['Machine Learning: This is a field of AI that focuses on developing algorithms that allow computers to learn from and make decisions based on data.',
#  'Machine learning encompasses a wide range of techniques, including supervised learning, unsupervised learning, and reinforcement learning.',
#  'Common algorithms include decision trees, support vector machines (SVMs), k-nearest neighbors (k-NN), and linear regression, among others']

# %%
# !pip install nltk
import nltk
nltk.download('averaged_perceptron_tagger')
for i in range(len(sent)):
    words=nltk.word_tokenize(sent[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    print(nltk.pos_tag(words))
# Out:
# ...
# [('Machine', 'NN'), ('Learning', 'NN'), (':', ':'), ('This', 'DT'), ('field', 'NN'), ('AI', 'NNP'), ('focuses', 'VBZ'), ('developing', 'VBG'), ('algorithms', 'RB'), ('allow', 'JJ'), ('computers', 'NNS'), ('learn', 'VBP'), ('make', 'VBP'), ('decisions', 'NNS'), ('based', 'VBN'), ('data', 'NNS'), ('.', '.')]
# [('Machine', 'NN'), ('learning', 'NN'), ('encompasses', 'NNS'), ('wide', 'JJ'), ('range', 'NN'), ('techniques', 'NNS'), (',', ','), ('including', 'VBG'), ('supervised', 'VBN'), ('learning', 'NN'), (',', ','), ('unsupervised', 'JJ'), ('learning', 'NN'), (',', ','), ('reinforcement', 'NN'), ('learning', 'NN'), ('.', '.')]
# ...

# %% [markdown]
# NAMED ENTITY RECOGNITION

# %%
link="""Machine Learning: This is a field of AI that focuses on developing algorithms that allow computers to learn from and make decisions based on data. Machine learning encompasses a wide range of techniques, including supervised learning, unsupervised learning, and reinforcement learning. Common algorithms include decision trees, support vector machines (SVMs), k-nearest neighbors (k-NN), and linear regression, among others"""

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
x= nltk.ne_chunk(link)
print(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-12e9b85fa3d3> in <cell line: 1>()
# ----> 1 x= nltk.ne_chunk(link)
#       2 print(x)
#
# /usr/local/lib/python3.10/dist-packages/nltk/chunk/__init__.py in ne_chunk(tagged_tokens, binary)
#     182         chunker_pickle = _MULTICLASS_NE_CHUNKER
#     183     chunker = load(chunker_pickle)
# --> 184     return chunker.parse(tagged_tokens)
#     185
#     186
#
# /usr/local/lib/python3.10/dist-packages/nltk/chunk/named_entity.py in parse(self, tokens)
#     125         Each token should be a pos-tagged word
#     126         """
# --> 127         tagged = self._tagger.tag(tokens)
#     128         tree = self._tagged_to_parse(tagged)
#     129         return tree
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/sequential.py in tag(self, tokens)
#      59         tags = []
# ...

# %%
import nltk
nltk.download('words')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')

link="""Machine Learning: This is a field of AI that focuses on developing algorithms that allow computers to learn from and make decisions based on data. Machine learning encompasses a wide range of techniques, including supervised learning, unsupervised learning, and reinforcement learning. Common algorithms include decision trees, support vector machines (SVMs), k-nearest neighbors (k-NN), and linear regression, among others"""

# Tokenize the text into words
tokens = nltk.word_tokenize(link)

# Tag the words with their part-of-speech
tagged_tokens = nltk.pos_tag(tokens)

# Perform named entity chunking
chunk=nltk.ne_chunk(tagged_tokens)
print(chunk)
# Out:
# (S
#   (GPE Machine/NN)
#   Learning/NN
#   :/:
#   This/DT
#   is/VBZ
#   a/DT
#   field/NN
#   of/IN
#   AI/NNP
#   that/WDT
#   focuses/VBZ
#   on/IN
#   developing/VBG
#   algorithms/RP
#   that/IN
#   allow/JJ
#   computers/NNS
#   to/TO
#   learn/VB
#   from/IN
#   and/CC
#   make/VB
#   decisions/NNS
#   based/VBN
#   on/IN
#   data/NNS
#   ./.
#   (PERSON Machine/NNP)
#   learning/VBG
#   encompasses/VBZ
#   a/DT
#   wide/JJ
#   range/NN
#   of/IN
#   techniques/NNS
#   ,/,
#   including/VBG
#   supervised/VBN
#   learning/NN
#   ,/,
#   unsupervised/JJ
#   learning/NN
#   ,/,
#   and/CC
#   reinforcement/NN
#   learning/NN
#   ./.
#   (ORGANIZATION Common/NNP)
#   algorithms/JJ
#   include/VBP
#   decision/NN
#   trees/NNS
#   ,/,
#   support/NN
#   vector/NN
#   machines/NNS
#   (/(
#   (ORGANIZATION SVMs/NNP)
#   )/)
#   ,/,
#   k-nearest/JJ
#   neighbors/NNS
#   (/(
#   k-NN/NN
#   )/)
#   ,/,
#   and/CC
#   linear/JJ
#   regression/NN
#   ,/,
#   among/IN
# ...

# %% [markdown]
# **TEXT PREPROCESSING IS CLEAR, NOW ITS THE TIME TO MAKE THE TEXT INTO VECTOR.......**
#
#
#
# ![Screenshot 2024-08-22 235121.png](data:image/png;base64,...)

# %% [markdown]
# #ONE HOT ENCODING![Screenshot 2024-08-22 233051.png](data:image/png;base64,...)

# %% [markdown]
# ADVANTAGE AND DISADVANTAGE (https://youtu.be/ENLEjGozrio?si=zF6luDhu2zULvLgL ) [2:03]
# ![Screenshot 2024-08-22 234033.png](data:image/png;base64,...)

# %% [markdown]
# BAG OF WORDS
#
# ![s.png](data:image/png;base64,...)

# %% [markdown]
# advantage and disadvantage of BOW
# ![s1.png](data:image/png;base64,...)

# %% [markdown]
# TF-TDF
# ![s3.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-08-23 012529.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-08-23 013919.png](data:image/png;base64,...)

# %% [markdown]
# Word embaded technique
# 2:45- 2:52 [https://youtu.be/ENLEjGozrio?si=ZyoGZ-5bneJhMM-D]

# %% [markdown]
# ![Screenshot 2024-08-23 235551.png](data:image/png;base64,...)

# %% [markdown]
# **WORD 2 VEC** - deep learning train model
# ![Screenshot 2024-08-24 000605.png](data:image/png;base64,...)
